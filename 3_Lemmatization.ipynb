# %% [markdown]
# **WordnetLemmatizer**
# Lemmatization technique is like stemming. The output we will get after lemmatization is called 'lemma', which is a root word rather then root stem. After lemmatization, we will be getting a valid word that means the same thing.

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer.lemmatize("going")
# Out:
# 'going'

# %% [markdown]
# **POS :**
#
# Noun - n (default)
#
# Verb - v
#
# Adjective - a
#
# Adverb - r

# %%
lemmatizer.lemmatize("going", pos='v')
# Out:
# 'go'

# %%
words = ["eating", "going", "gone", "history", "programming", "programs", "finally", "finalize"]
for word in words:
  print(word+" --> "+lemmatizer.lemmatize(word, pos='v'))
# Out:
# eating --> eat
# going --> go
# gone --> go
# history --> history
# programming --> program
# programs --> program
# finally --> finally
# finalize --> finalize

# %%
lemmatizer.lemmatize("goes")
# Out:
# 'go'

# %%
lemmatizer.lemmatize("fairly", pos='v'), lemmatizer.lemmatize("sportingly", pos='v')
# Out:
# ('fairly', 'sportingly')

# %% [markdown]
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This class uses morphy() function to the WordNet CorpusReaer class to find a lemma.
#
# Lemmatization takes more time compared to Stemming.
#
# Applications: Q&A, chatbots, text summarization
