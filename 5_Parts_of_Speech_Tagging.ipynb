# %% [markdown]
# | Tag  | Meaning                               | Example         |
# | ---- | ------------------------------------- | --------------- |
# | CC   | Coordinating conjunction              | and, but        |
# | CD   | Cardinal number                       | 1, 100          |
# | DT   | Determiner                            | the, a          |
# | EX   | Existential there                     | there           |
# | FW   | Foreign word                          | bonjour         |
# | IN   | Preposition/Subordinating conjunction | in, on, because |
# | JJ   | Adjective                             | beautiful       |
# | JJR  | Comparative adjective                 | bigger          |
# | JJS  | Superlative adjective                 | biggest         |
# | LS   | List item marker                      | 1., A.          |
# | MD   | Modal                                 | can, should     |
# | NN   | Noun singular                         | dog             |
# | NNS  | Noun plural                           | dogs            |
# | NNP  | Proper noun singular                  | Hyderabad       |
# | NNPS | Proper noun plural                    | Indians         |
# | PDT  | Predeterminer                         | all, both       |
# | POS  | Possessive ending                     | 's              |
# | PRP  | Personal pronoun                      | he, she         |
# | RB   | Adverb                                | quickly         |
# | RBR  | Comparative adverb                    | faster          |
# | RBS  | Superlative adverb                    | fastest         |
# | RP   | Particle                              | up, off         |
# | SYM  | Symbol                                | %, +            |
# | TO   | to                                    | to              |
# | UH   | Interjection                          | wow, oh         |
# | VB   | Verb base form                        | go              |
# | VBD  | Verb past tense                       | went            |
# | VBG  | Verb gerund/present participle        | going           |
# | VBN  | Verb past participle                  | gone            |
# | VBP  | Verb non-3rd person singular present  | go              |
# | VBZ  | Verb 3rd person singular present      | goes            |
# | WDT  | Wh-determiner                         | which, that     |
# | WP   | Wh-pronoun                            | who             |
# | WP$  | Possessive wh-pronoun                 | whose           |
# | WRB  | Wh-adverb                             | where, when     |

# %%
paragraph = """I have three visions for India. In 3000 years of our history people from all over the world have come and invaded us, captured our lands, conquered our minds. From Alexander onwards the Greeks, the Turks, the Moguls, the Portuguese, the British, the French, the Dutch, all of them came and looted us, took over what was ours. Yet we have not done this to any other nation. We have not conquered anyone. We have not grabbed their land, their culture and their history and tried to enforce our way of life on them. Why? Because we respect the freedom of others. That is why my FIRST VISION is that of FREEDOM. I believe that India got its first vision of this in 1857, when we started the war of Independence. It is this freedom that we must protect and nurture and build on. If we are not free, no one will respect us.

We have 10 percent growth rate in most areas. Our poverty levels are falling. Our achievements are being globally recognised today. Yet we lack the self-confidence to see ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect? MY SECOND VISION for India is DEVELOPMENT. For fifty years we have been a developing nation. It is time we see ourselves as a developed nation. We are among top five nations in the world in terms of GDP."""

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import nltk
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['I have three visions for India.',
#  'In 3000 years of our history people from all over the world have come and invaded us, captured our lands, conquered our minds.',
#  'From Alexander onwards the Greeks, the Turks, the Moguls, the Portuguese, the British, the French, the Dutch, all of them came and looted us, took over what was ours.',
#  'Yet we have not done this to any other nation.',
#  'We have not conquered anyone.',
#  'We have not grabbed their land, their culture and their history and tried to enforce our way of life on them.',
#  'Why?',
#  'Because we respect the freedom of others.',
#  'That is why my FIRST VISION is that of FREEDOM.',
#  'I believe that India got its first vision of this in 1857, when we started the war of Independence.',
#  'It is this freedom that we must protect and nurture and build on.',
#  'If we are not free, no one will respect us.',
#  'We have 10 percent growth rate in most areas.',
#  'Our poverty levels are falling.',
# ...

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
## Find out 'pos' tag
import nltk
nltk.download('averaged_perceptron_tagger_eng')

for i in range(len(sentences)):
  words = nltk.word_tokenize(sentences[i])
  words = [word for word in words if word not in set(stopwords.words('english'))]
  words = nltk.pos_tag(words)
  print(words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('I', 'PRP'), ('three', 'CD'), ('visions', 'NNS'), ('India', 'NNP'), ('.', '.')]
# [('In', 'IN'), ('3000', 'CD'), ('years', 'NNS'), ('history', 'NN'), ('people', 'NNS'), ('world', 'NN'), ('come', 'VBP'), ('invaded', 'VBN'), ('us', 'PRP'), (',', ','), ('captured', 'VBD'), ('lands', 'NNS'), (',', ','), ('conquered', 'VBD'), ('minds', 'NNS'), ('.', '.')]
# [('From', 'IN'), ('Alexander', 'NNP'), ('onwards', 'NNS'), ('Greeks', 'NNP'), (',', ','), ('Turks', 'NNP'), (',', ','), ('Moguls', 'NNP'), (',', ','), ('Portuguese', 'NNP'), (',', ','), ('British', 'NNP'), (',', ','), ('French', 'NNP'), (',', ','), ('Dutch', 'NNP'), (',', ','), ('came', 'VBD'), ('looted', 'JJ'), ('us', 'PRP'), (',', ','), ('took', 'VBD'), ('.', '.')]
# [('Yet', 'RB'), ('done', 'VBN'), ('nation', 'NN'), ('.', '.')]
# ...

# %%
## Apply pos tag
print(nltk.pos_tag("Taj mahal is beautiful monument".split()))
# Out:
# [('Taj', 'NNP'), ('mahal', 'NN'), ('is', 'VBZ'), ('beautiful', 'JJ'), ('monument', 'NN')]

# %% [markdown]
# **Named Entity Recognition (NER)** is an NLP technique used to identify and classify important entities in text into predefined categories.

# %% [markdown]
# | Entity Type        | Meaning                                  | Example           |
# | ------------------ | ---------------------------------------- | ----------------- |
# | PERSON             | Names of people                          | John, Virat Kohli |
# | ORGANIZATION (ORG) | Company/Institution names                | Google, Infosys   |
# | LOCATION (LOC)     | Geographic locations                     | India, Hyderabad  |
# | GPE                | Geo-Political Entity                     | USA, Telangana    |
# | DATE               | Dates                                    | 21 May 2026       |
# | TIME               | Time expressions                         | 10 AM             |
# | MONEY              | Monetary values                          | ₹500, $100        |
# | PERCENT            | Percentages                              | 75%               |
# | PRODUCT            | Product names                            | iPhone 15         |
# | EVENT              | Events                                   | Olympics          |
# | LANGUAGE           | Languages                                | English, Telugu   |
# | FACILITY (FAC)     | Buildings/airports/bridges               | Charminar Airport |
# | NORP               | Nationalities/religions/political groups | Indian, Hindu     |

# %%
sentence = "The Eiffel tower was built from 1887 to 1889 by french engineer"

# %%
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import nltk
words = nltk.word_tokenize(sentence)

# %%
tag_elements = nltk.pos_tag(words)

# %%
print(nltk.ne_chunk(tag_elements))
# Out:
# (S
#   The/DT
#   (GPE Eiffel/NNP)
#   tower/NN
#   was/VBD
#   built/VBN
#   from/IN
#   1887/CD
#   to/TO
#   1889/CD
#   by/IN
#   french/JJ
#   engineer/NN)
